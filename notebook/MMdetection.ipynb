# %% [markdown]
# # MMdetection

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'  # A6000 GPU 선택 (nvidia-smi에서 확인한 번호)

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU capability: {torch.cuda.get_device_capability(0)}")
# Out:
# PyTorch version: 2.5.1+cu118
# CUDA available: True
# GPU count: 1
# GPU name: NVIDIA RTX A6000
# GPU capability: (8, 6)

# %%
# Input 데이터
# COCO

# %%
import mmdet
# Out:
# /home/hyeonjin/tomato-detection-agentic/.venv/lib/python3.12/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import mmdet
#
# File ~/tomato-detection-agentic/.venv/lib/python3.12/site-packages/mmdet/__init__.py:16
#      13 mmengine_maximum_version = '1.0.0'
#      14 mmengine_version = digit_version(mmengine.__version__)
# ---> 16 assert (mmcv_version >= digit_version(mmcv_minimum_version)
#      17         and mmcv_version < digit_version(mmcv_maximum_version)), \
#      18     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
#      19     f'Please install mmcv>={mmcv_minimum_version}, <{mmcv_maximum_version}.'
#      21 assert (mmengine_version >= digit_version(mmengine_minimum_version)
#      22         and mmengine_version < digit_version(mmengine_maximum_version)), \
#      23     f'MMEngine=={mmengine.__version__} is used but incompatible. ' \
#      24     f'Please install mmengine>={mmengine_minimum_version}, ' \
#      25     f'<{mmengine_maximum_version}.'
#      27 __all__ = ['__version__', 'version_info', 'digit_version']
#
# AssertionError: MMCV==1.7.2 is used but incompatible. Please install mmcv>=2.0.0rc4, <2.2.0.

# %%
import mmcv
print(f"Current mmcv version: {mmcv.__version__}")
# Out:
# Current mmcv version: 1.7.2

# %%
import mmdet
print(f"MMDetection version: {mmdet.__version__}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import mmdet
#       2 print(f"MMDetection version: {mmdet.__version__}")
#
# File ~/tomato-detection-agentic/.venv/lib/python3.12/site-packages/mmdet/__init__.py:16
#      13 mmengine_maximum_version = '1.0.0'
#      14 mmengine_version = digit_version(mmengine.__version__)
# ---> 16 assert (mmcv_version >= digit_version(mmcv_minimum_version)
#      17         and mmcv_version < digit_version(mmcv_maximum_version)), \
#      18     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
#      19     f'Please install mmcv>={mmcv_minimum_version}, <{mmcv_maximum_version}.'
#      21 assert (mmengine_version >= digit_version(mmengine_minimum_version)
#      22         and mmengine_version < digit_version(mmengine_maximum_version)), \
#      23     f'MMEngine=={mmengine.__version__} is used but incompatible. ' \
#      24     f'Please install mmengine>={mmengine_minimum_version}, ' \
#      25     f'<{mmengine_maximum_version}.'
#      27 __all__ = ['__version__', 'version_info', 'digit_version']
#
# AssertionError: MMCV==1.7.2 is used but incompatible. Please install mmcv>=2.0.0rc4, <2.2.0.
