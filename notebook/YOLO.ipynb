# %% [markdown]
# # YOLO

# %% [markdown]
# ## YOLOv11

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'  # A6000 GPU

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU capability: {torch.cuda.get_device_capability(0)}")
# Out:
# PyTorch version: 2.5.1+cu118
# CUDA available: True
# GPU count: 1
# GPU name: NVIDIA RTX A6000
# GPU capability: (8, 6)

# %%
import json
import shutil
import platform
import random
import subprocess
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image
from pathlib import Path
from collections import Counter, OrderedDict
from typing import Any, Dict, List, Optional, Tuple

import torchvision
from torch.utils.data import DataLoader
from torchvision import transforms as T
from PIL import Image
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm

from ultralytics import YOLO
import yaml

import ultralytics
print(ultralytics.__version__)  # 8.3.0 이상이어야 YOLOv11 지원
import yaml
# Out:
# 8.3.243

# %%
# 프로젝트 루트 탐색
# 한 번만 찾고 고정
def find_project_root(marker_filename=".project-root"):
    current_dir = os.path.abspath(os.getcwd())
    while True:
        if os.path.isfile(os.path.join(current_dir, marker_filename)):
            return current_dir
        parent_dir = os.path.dirname(current_dir)
        if parent_dir == current_dir:
            raise FileNotFoundError(f"Could not find {marker_filename} in any parent directory.")
        current_dir = parent_dir
        
# 경로/출력 폴더 생성(find_project_root() 호출 후 사용)
def ensure_dir(path):
    # 디렉토리 없으면 생성
    os.makedirs(path, exist_ok=True)

PROJECT_ROOT = find_project_root()
def get_project_path(*paths):
    return os.path.join(PROJECT_ROOT, *paths)

# %%
# 프로젝트 경로 확인
print(f"Project Root: {PROJECT_ROOT}")

# 데이터 경로 설정
data_root = get_project_path("data/TomatOD_COCO_3")

# 데이터 구조 확인
print("\n=== 데이터 구조 ===")
for split in ['train', 'val', 'test']:
    split_path = os.path.join(data_root, split)
    img_dir = os.path.join(split_path, 'images')
    ann_file = os.path.join(split_path, 'custom_' + split + '.json')
    
    if os.path.exists(img_dir):
        img_count = len([f for f in os.listdir(img_dir) if f.endswith(('.jpg', '.png'))])
        print(f"{split:5s}: {img_count:3d} images")
# Out:
# Project Root: /home/hyeonjin/tomato-detection-agentic
#
# === 데이터 구조 ===
# train: 193 images
# val  :  54 images
# test :  30 images

# %%
# YOLO 데이터 형식 확인

def coco_to_yolo(coco_json_path, output_dir, img_width=2000, img_height=2000):
    """
    COCO JSON을 YOLO txt 형식으로 변환
    YOLO 형식: <class_id> <x_center> <y_center> <width> <height> (normalized 0~1)
    """
    with open(coco_json_path, 'r') as f:
        coco_data = json.load(f)
    
    # Category ID mapping (COCO → YOLO: 0-based index)
    cat_id_to_yolo = {cat['id']: idx for idx, cat in enumerate(coco_data['categories'])}
    
    # Image ID to filename mapping
    img_id_to_info = {img['id']: img for img in coco_data['images']}
    
    # Annotations grouped by image_id
    anns_by_img = {}
    for ann in coco_data['annotations']:
        img_id = ann['image_id']
        if img_id not in anns_by_img:
            anns_by_img[img_id] = []
        anns_by_img[img_id].append(ann)
    
    os.makedirs(output_dir, exist_ok=True)
    
    # Convert each image's annotations
    for img_id, anns in anns_by_img.items():
        img_info = img_id_to_info[img_id]
        img_filename = img_info['file_name']
        txt_filename = os.path.splitext(img_filename)[0] + '.txt'
        txt_path = os.path.join(output_dir, txt_filename)
        
        # Get image dimensions
        img_w = img_info.get('width', img_width)
        img_h = img_info.get('height', img_height)
        
        with open(txt_path, 'w') as f:
            for ann in anns:
                # COCO bbox: [x, y, width, height] (absolute)
                x, y, w, h = ann['bbox']
                
                # Convert to YOLO format (normalized center coordinates)
                x_center = (x + w / 2) / img_w
                y_center = (y + h / 2) / img_h
                w_norm = w / img_w
                h_norm = h / img_h
                
                # YOLO class ID (0-based)
                class_id = cat_id_to_yolo[ann['category_id']]
                
                # Write: <class_id> <x_center> <y_center> <width> <height>
                f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {w_norm:.6f} {h_norm:.6f}\n")
    
    print(f" Converted {len(anns_by_img)} annotations to YOLO format")
    return len(anns_by_img)

# %%
# YOLO 데이터셋 폴더 생성
yolo_dataset_root = get_project_path("data/TomatOD_YOLO_3")
ensure_dir(yolo_dataset_root)

print("=== COCO → YOLO 변환 시작 ===\n")

for split in ['train', 'val', 'test']:
    print(f"\n[{split.upper()}]")
    
    # 입력 경로
    coco_json = get_project_path(f"data/TomatOD_COCO_3/{split}/custom_{split}.json")
    src_img_dir = get_project_path(f"data/TomatOD_COCO_3/{split}/images")
    
    # 출력 경로
    dst_img_dir = os.path.join(yolo_dataset_root, split, "images")
    dst_label_dir = os.path.join(yolo_dataset_root, split, "labels")
    
    ensure_dir(dst_img_dir)
    ensure_dir(dst_label_dir)
    
    # 1. 이미지 복사
    print(f"  Copying images...")
    if os.path.exists(src_img_dir):
        for img_file in os.listdir(src_img_dir):
            if img_file.endswith(('.jpg', '.png')):
                shutil.copy(
                    os.path.join(src_img_dir, img_file),
                    os.path.join(dst_img_dir, img_file)
                )
    
    # 2. COCO → YOLO 변환
    print(f"  Converting annotations...")
    coco_to_yolo(coco_json, dst_label_dir)

print("\n✅ YOLO 데이터셋 생성 완료!")
# Out:
# === COCO → YOLO 변환 시작 ===
#
#
# [TRAIN]
#   Copying images...
#   Converting annotations...
#  Converted 193 annotations to YOLO format
#
# [VAL]
#   Copying images...
#   Converting annotations...
#  Converted 54 annotations to YOLO format
#
# [TEST]
#   Copying images...
#   Converting annotations...
#  Converted 30 annotations to YOLO format
#
# ✅ YOLO 데이터셋 생성 완료!

# %%
from pathlib import Path

# PROJECT_ROOT를 Path 객체로 변환
project_path = Path(PROJECT_ROOT)

# 데이터 경로 설정
data_root = project_path / "data" / "TomatOD_YOLO_3"
train_dir = data_root / "train"
val_dir = data_root / "val" 
test_dir = data_root / "test"

train_images_dir = data_root / "train" / "images"
val_images_dir = data_root / "val" / "images"
test_images_dir = data_root / "test" / "images"

train_labels_dir = data_root / "train" / "labels"
val_labels_dir = data_root / "val" / "labels"
test_labels_dir = data_root / "test" / "labels"



# 클래스 정보
class_names = ["fully-ripe", "semi-ripe", "unripe"]
num_classes = len(class_names)
id2label = {i: name for i, name in enumerate(class_names)}
label2id = {name: i for i, name in enumerate(class_names)}

print(f"Classes: {class_names}")
print(f"Number of classes: {num_classes}")
print(f"Data root: {data_root}")
# Out:
# Classes: ['fully-ripe', 'semi-ripe', 'unripe']
# Number of classes: 3
# Data root: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3

# %%
from urllib.request import urlretrieve
from pathlib import Path

# 다운로드할 모델 크기 선택
model_size = 'm'

# YOLOv11 모델
model_url = f"https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11{model_size}.pt"
model_path = "yolo11m.pt"

# 저장 경로
save_path = Path(f"yolo11{model_size}.pt")

if not Path(model_path).exists():
    urlretrieve(model_url, model_path)

# %%
# 하이퍼파라미터
batch_size = 16
learning_rate = 0.01
num_epochs = 100
image_size = 640
confidence_threshold = 0.25
iou_threshold = 0.45

# %%
# 로드
model = YOLO(model_path)

# 샘플 라벨 파일 확인
if train_labels_dir.exists():
    label_files = list(train_labels_dir.glob("*.txt"))
    if label_files:
        sample_label_file = label_files[0]
        print(f"Sample label file: {sample_label_file.name}")
        
        with open(sample_label_file, 'r') as f:
            lines = f.readlines()
            print(f"Number of objects: {len(lines)}")
            for i, line in enumerate(lines[:3]):  # 처음 3개만 출력
                parts = line.strip().split()
                if len(parts) >= 5:
                    class_id, x_center, y_center, width, height = parts[:5]
                    print(f"  Object {i+1}: class={class_id} ({class_names[int(class_id)]}), "
                          f"center=({x_center}, {y_center}), size=({width}, {height})")

# 샘플 이미지 확인
if train_images_dir.exists():
    image_files = list(train_images_dir.glob("*.jpg")) + list(train_images_dir.glob("*.png"))
    if image_files:
        sample_image_file = image_files[0]
        sample_image = Image.open(sample_image_file)
        print(f"Sample image: {sample_image_file.name}")
        print(f"Image size: {sample_image.size}")
        print(f"Image mode: {sample_image.mode}")
# Out:
# Sample label file: stereo20190406_054921_p0_snap_454.txt
# Number of objects: 7
#   Object 1: class=1 (semi-ripe), center=(0.661000, 0.147500), size=(0.077000, 0.077000)
#   Object 2: class=2 (unripe), center=(0.365000, 0.104500), size=(0.077000, 0.077000)
#   Object 3: class=0 (fully-ripe), center=(0.799500, 0.352000), size=(0.044000, 0.044000)
# Sample image: stereo20190405_132743_p0_snap_488.jpg
# Image size: (2000, 2000)
# Image mode: RGB

# %%
import yaml
from pathlib import Path

# Config 파일 로드
config_path = project_path / "configs" / "yolov11" / "yolov11_3class.yaml"

with open(config_path, 'r') as f:
    config = yaml.safe_load(f)


# Config 섹션별로 변수 할당
experiment_config = config['experiment']
model_config = config['model']
data_config = config['data']
training_config = config['training']
evaluation_config = config['evaluation']
logging_config = config['logging']
hardware_config = config['hardware']

# %%
# Config에서 데이터 정보 추출
class_names = data_config['class_names']
num_classes = data_config['num_classes']
data_root = project_path / data_config['data_root']

# YOLO data.yaml 생성
data_yaml_content = {
    'path': str(data_root),
    'train': 'train/images',
    'val': 'val/images', 
    'test': 'test/images',
    'nc': num_classes,
    'names': class_names
}

data_yaml_path = data_root / "data.yaml"
data_yaml_path.parent.mkdir(parents=True, exist_ok=True)

with open(data_yaml_path, 'w') as f:
    yaml.dump(data_yaml_content, f, default_flow_style=False)

print(f"YOLO data.yaml created at: {data_yaml_path}")
print("Content:")
print(yaml.dump(data_yaml_content, default_flow_style=False))
# Out:
# YOLO data.yaml created at: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/data.yaml
# Content:
# names:
# - fully-ripe
# - semi-ripe
# - unripe
# nc: 3
# path: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3
# test: test/images
# train: train/images
# val: val/images

# %%
# 학습 파라미터 설정
train_args = {
    # 데이터 설정
    'data': str(data_yaml_path),
    
    # 기본 학습 설정
    'epochs': training_config['epochs'],
    'batch': data_config['batch_size'],
    'imgsz': data_config['imgsz'],
    'device': 0,
    
    # 옵티마이저 설정
    'lr0': model_config['lr0'],
    'lrf': model_config['lrf'],
    'momentum': model_config['momentum'],
    'weight_decay': model_config['weight_decay'],
    
    # Loss 계수
    'box': model_config['box'],
    'cls': model_config['cls'],
    'dfl': model_config['dfl'],
    
    # 학습 설정
    'patience': training_config['patience'],
    'save': training_config['save'],
    'save_period': training_config['save_period'],
    'cache': training_config['cache'],
    'val': training_config['val'],
    'project': training_config['project'],
    'name': training_config['name'],
    'exist_ok': training_config['exist_ok'],
    'plots': training_config['plots'],
    'amp': training_config['amp'],
    'fraction': training_config['fraction'],
    'profile': training_config['profile'],
    'freeze': training_config['freeze'],
    'multi_scale': training_config['multi_scale'],
    'overlap_mask': training_config['overlap_mask'],
    'mask_ratio': training_config['mask_ratio'],
    'dropout': training_config['dropout'],
    
    
    # 데이터 증강 설정
    'hsv_h': data_config['augmentation']['hsv_h'],
    'hsv_s': data_config['augmentation']['hsv_s'],
    'hsv_v': data_config['augmentation']['hsv_v'],
    'degrees': data_config['augmentation']['degrees'],
    'translate': data_config['augmentation']['translate'],
    'scale': data_config['augmentation']['scale'],
    'shear': data_config['augmentation']['shear'],
    'perspective': data_config['augmentation']['perspective'],
    'flipud': data_config['augmentation']['flipud'],
    'fliplr': data_config['augmentation']['fliplr'],
    'mosaic': data_config['augmentation']['mosaic'],
    'mixup': data_config['augmentation']['mixup'],
    
    # 기타 설정 (hardware 섹션에서 가져오기)
    'seed': config['experiment']['seed'],
    'deterministic': config['hardware']['deterministic'],
    'cos_lr': config['hardware']['cos_lr'],  # training_config가 아닌 hardware에서 가져오기
    'close_mosaic': config['hardware']['close_mosaic']  # training_config가 아닌 hardware에서 가져오기
}

# %%
# Config에서 모델 설정 추출
model_config = config['model']
model_name = model_config['pretrained_path']

# YOLOv11 모델 로드
model = YOLO(model_name)
print(f"YOLOv11 model loaded: {model_name}")
print(f"Model size: {model_config['model_size']}")

# 모델 정보 출력
try:
    model_info = model.info(verbose=False)
    print(f"Model parameters: {model_info}")
except:
    print("Model info not available")
# Out:
# YOLOv11 model loaded: yolo11m.pt
# Model size: m
# Model parameters: None

# %%
# 학습 실행
print("=" * 60)
print("YOLO TRAINING STARTED")
print("=" * 60)
print(f"Experiment: {config['experiment']['name']}")
print(f"Model: {model_config['arch_name']} ({model_config['model_size']})")
print(f"Dataset: {data_config['dataset_name']}")
print(f"Epochs: {training_config['epochs']}")
print(f"Batch size: {data_config['batch_size']}")
print(f"Device: {train_args['device']}")
print("=" * 60)

# 학습 시작
results = model.train(**train_args)

print("\nTraining completed!")
print(f"Results: {results}")
# Out:
# ============================================================
# YOLO TRAINING STARTED
# ============================================================
# Experiment: yolo11_tomato_3class_exp001
# Model: yolov11 (m)
# Dataset: TomatOD_YOLO_3
# Epochs: 50
# Batch size: 8
# Device: 0
# ============================================================
# New https://pypi.org/project/ultralytics/8.3.246 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.243 🚀 Python-3.12.3 torch-2.5.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48550MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=exp/yolo, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1413337  ultralytics.nn.modules.head.Detect           [3, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,055,321 parameters, 20,055,305 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 61.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4403.6±535.6 MB/s, size: 706.9 KB)
# train: Scanning /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/labels... 193 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 193/193 2.9Kit/s 0.1s
# train: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/images/stereo20190405_133623_p1_snap_027.jpg: 1 duplicate labels removed
# train: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/images/stereo20190405_133623_p1_snap_036.jpg: 1 duplicate labels removed
# train: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/images/stereo20190406_054921_p0_snap_414.jpg: 1 duplicate labels removed
# train: New cache created: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2561.5±1810.7 MB/s, size: 615.1 KB)
# val: Scanning /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/labels... 54 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 54/54 1.8Kit/s 0.0s
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190405_133623_p2_snap_043.jpg: 1 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190405_133623_p2_snap_087.jpg: 2 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190406_054921_p0_snap_544.jpg: 1 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190406_054921_p0_snap_822.jpg: 1 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190406_065607_p0_snap_080.jpg: 1 duplicate labels removed
# val: New cache created: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/labels.cache
# Plotting labels to /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.23G      1.694      2.553      1.222         16        640: 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.0it/s 2.0s0.4ss
#                    all         54        575       0.42      0.616      0.509      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.99G      1.513      1.375      1.153         20        640: 100% ━━━━━━━━━━━━ 25/25 9.4it/s 2.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.6it/s 0.9s0.4s
#                    all         54        575      0.462      0.605      0.451      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.99G      1.573      1.353      1.174         12        640: 100% ━━━━━━━━━━━━ 25/25 9.8it/s 2.6s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.6it/s 0.9s0.4s
#                    all         54        575      0.139      0.167     0.0783     0.0591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.99G      1.506      1.357      1.156          3        640: 100% ━━━━━━━━━━━━ 25/25 9.7it/s 2.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.1it/s 0.8s0.4s
#                    all         54        575      0.232      0.143      0.124     0.0821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.99G      1.407      1.266      1.119         13        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.3it/s 0.8s0.3s
#                    all         54        575      0.431      0.638      0.421      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.99G       1.41       1.13      1.135         11        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.3it/s 0.8s0.3s
#                    all         54        575      0.454      0.555      0.534      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4.99G      1.426      1.065      1.131          5        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.2it/s 0.8s0.3s
#                    all         54        575       0.55      0.633      0.608       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      4.99G      1.415      1.153      1.102         10        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.4it/s 0.7s0.3s
#                    all         54        575      0.386      0.529      0.329      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      4.99G      1.396      1.122      1.092         23        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.2it/s 0.8s0.3s
#                    all         54        575      0.416      0.617      0.363      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      4.99G      1.392      1.132      1.086         23        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 5.8it/s 0.7s0.3s
#                    all         54        575      0.454      0.639      0.557      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      4.99G      1.302      1.051      1.054          4        640: 100% ━━━━━━━━━━━━ 25/25 9.5it/s 2.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 12.3it/s 0.3s.6s
#                    all         54        575      0.689      0.662      0.691      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      4.99G      1.318     0.9923      1.081         15        640: 100% ━━━━━━━━━━━━ 25/25 9.7it/s 2.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 12.7it/s 0.3s.6s
#                    all         54        575      0.667       0.67      0.674      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      4.99G      1.304      1.025      1.054          3        640: 100% ━━━━━━━━━━━━ 25/25 9.8it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 12.8it/s 0.3s.6s
#                    all         54        575      0.659      0.748      0.709      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      4.99G      1.306     0.9834      1.088          5        640: 100% ━━━━━━━━━━━━ 25/25 9.4it/s 2.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 13.0it/s 0.3s.6s
#                    all         54        575      0.665      0.732      0.743       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         5G      1.271     0.9714      1.049         26        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.2s
#                    all         54        575      0.726      0.725      0.727      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         5G      1.411      1.242      1.088         12        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 13.0it/s 0.3s.6s
#                    all         54        575      0.582      0.736      0.709      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         5G      1.247     0.9496      1.049          5        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 13.1it/s 0.3s.6s
#                    all         54        575      0.731       0.67      0.713      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         5G      1.258     0.9674      1.041         46        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 12.9it/s 0.3s.6s
#                    all         54        575      0.617      0.726      0.715      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         5G      1.281     0.9519      1.057          9        640: 100% ━━━━━━━━━━━━ 25/25 9.7it/s 2.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 12.6it/s 0.3s.6s
#                    all         54        575      0.649      0.574      0.593      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         5G      1.291     0.9248      1.064          6        640: 100% ━━━━━━━━━━━━ 25/25 9.8it/s 2.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 11.6it/s 0.3s.4s
#                    all         54        575      0.682      0.685      0.662      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         5G      1.235     0.8992      1.025          7        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 12.8it/s 0.3s.6s
#                    all         54        575      0.654      0.678      0.678      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         5G      1.231     0.9068      1.022          4        640: 100% ━━━━━━━━━━━━ 25/25 9.8it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 13.0it/s 0.3s.6s
#                    all         54        575       0.65      0.729       0.71      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         5G      1.259      0.883      1.028         14        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 13.2it/s 0.3s.6s
#                    all         54        575       0.67      0.729      0.726      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         5G      1.213     0.8947      1.015          5        640: 100% ━━━━━━━━━━━━ 25/25 9.9it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 13.0it/s 0.3s.6s
#                    all         54        575      0.654      0.748      0.722      0.472
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 14, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 24 epochs completed in 0.025 hours.
# Optimizer stripped from /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3/weights/last.pt, 40.5MB
# Optimizer stripped from /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3/weights/best.pt, 40.5MB
#
# Validating /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3/weights/best.pt...
# Ultralytics 8.3.243 🚀 Python-3.12.3 torch-2.5.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48550MiB)
# YOLO11m summary (fused): 125 layers, 20,032,345 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s0.4s
#                    all         54        575      0.665      0.732      0.743       0.49
#             fully-ripe         43         93      0.568       0.86      0.755      0.494
#              semi-ripe         38        106      0.771      0.509      0.663      0.462
#                 unripe         54        376      0.657      0.827      0.812      0.515
# Speed: 0.1ms preprocess, 3.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3
#
# Training completed!
# Results: ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x71f45d970a70>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[          1,           1,           1, ...,   0.0016779,  0.00083894,           0],
#        [          1,           1,           1, ...,   0.0014859,  0.00074297,           0],
#        [          1,           1,           1, ...,  0.00036339,  0.00018169,           0]], shape=(3, 1000)), 'Recall', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.13365,     0.13365,      0.1866, ...,           0,           0,           0],
#        [    0.12999,     0.12999,     0.18372, ...,           0,           0,           0],
#        [     0.0515,      0.0515,     0.12653, ...,           0,           0,           0]], shape=(3, 1000)), 'Confidence', 'F1'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
# ...
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[   0.072095,    0.072095,     0.10391, ...,           1,           1,           1],
#        [   0.070022,    0.070022,     0.10223, ...,           1,           1,           1],
#        [   0.026551,    0.026551,    0.068366, ...,           1,           1,           1]], shape=(3, 1000)), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.91398,     0.91398,     0.91398, ...,           0,           0,           0],
#        [    0.90566,     0.90566,     0.90566, ...,           0,           0,           0],
#        [    0.85372,     0.85372,      0.8484, ...,           0,           0,           0]], shape=(3, 1000)), 'Confidence', 'Recall']]
# fitness: np.float64(0.4901503218715367)
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.49406,     0.46179,      0.5146])
# names: {0: 'fully-ripe', 1: 'semi-ripe', 2: 'unripe'}
# nt_per_class: array([ 93, 106, 376])
# nt_per_image: array([43, 38, 54])
# results_dict: {'metrics/precision(B)': 0.6654950827834935, 'metrics/recall(B)': 0.7321798318575669, 'metrics/mAP50(B)': 0.7434016406986889, 'metrics/mAP50-95(B)': 0.4901503218715367, 'fitness': 0.4901503218715367}
# save_dir: PosixPath('/home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train3')
# speed: {'preprocess': 0.10472486987796233, 'inference': 3.024095889284379, 'loss': 0.000548871294422834, 'postprocess': 1.1744688521570492}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU count: {torch.cuda.device_count()}")

if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU capability: {torch.cuda.get_device_capability(0)}")
# Out:
# PyTorch version: 2.5.1+cu118
# CUDA available: True
# CUDA version: 11.8
# GPU count: 1
# GPU name: NVIDIA RTX A6000
# GPU capability: (8, 6)

# %%
print("=" * 60)
print("EXPERIMENTAL ENVIRONMENT")
print("=" * 60)

# 하드웨어 정보
print("\n[Hardware]")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"  Device: {device}")

if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    print(f"  GPU: {gpu_name}")
    print(f"  GPU Memory: {gpu_memory:.1f} GB")
    print(f"  CUDA Version: {torch.version.cuda}")
    if torch.backends.cudnn.is_available():
        print(f"  cuDNN Version: {torch.backends.cudnn.version()}")
# Out:
# ============================================================
# EXPERIMENTAL ENVIRONMENT
# ============================================================
#
# [Hardware]
#   Device: cuda
#   GPU: NVIDIA RTX PRO 6000 Blackwell Max-Q Workstation Edition
#   GPU Memory: 95.0 GB
#   CUDA Version: 11.8
#   cuDNN Version: 90100

# %% [markdown]
# # YOLO v12

# %%
import urllib.request
from pathlib import Path

# 다운로드할 모델 크기 선택 (n, s, m, l, x)
model_size = 'm'  # nano, small, medium, large, xlarge

# YOLOv12 모델 URL (Ultralytics 공식)
model_url = f"https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12{model_size}.pt"

# 저장 경로
save_path = Path(f"yolo12{model_size}.pt")

# 다운로드
print(f"Downloading YOLOv12-{model_size} from {model_url}...")
urllib.request.urlretrieve(model_url, save_path)
# Out:
# Downloading YOLOv12-m from https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12m.pt...
# (PosixPath('yolo12m.pt'), <http.client.HTTPMessage at 0x7ff13f654890>)

# %%
import yaml

# 데이터 경로 설정
data_root = get_project_path("data/TomatOD_YOLO_3")

project_path = Path(PROJECT_ROOT)
data_root = project_path / "data" / "TomatOD_YOLO_3"
train_dir = data_root / "train"
val_dir = data_root / "val" 
test_dir = data_root / "test"

train_images_dir = data_root / "train" / "images"
val_images_dir = data_root / "val" / "images"
test_images_dir = data_root / "test" / "images"

train_labels_dir = data_root / "train" / "labels"
val_labels_dir = data_root / "val" / "labels"
test_labels_dir = data_root / "test" / "labels"

data_yaml_path = data_root / "data.yaml"

# 클래스 정보
class_names = ["fully-ripe", "semi-ripe", "unripe"]
num_classes = len(class_names)
id2label = {i: name for i, name in enumerate(class_names)}
label2id = {name: i for i, name in enumerate(class_names)}

print(f"Classes: {class_names}")
print(f"Number of classes: {num_classes}")
print(f"data.yaml created at: {data_yaml_path}")
# Out:
# Classes: ['fully-ripe', 'semi-ripe', 'unripe']
# Number of classes: 3
# data.yaml created at: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/data.yaml

# %%
# config 파일 로드
import yaml
from pathlib import Path
from ultralytics import YOLO

project_path = Path(PROJECT_ROOT)
config_path = project_path / "configs" / "yolov12" / "yolov12_3class.yaml"
print(f"Config path: {config_path}")

with open(config_path, 'r', encoding='utf-8') as f:
    config = yaml.safe_load(f)
# Out:
# Config path: /home/hyeonjin/tomato-detection-agentic/configs/yolov12/yolov12_3class.yaml

# %%
# 학습 파라미터 설정 및 모델 파라미터 추출 
model_config = config['model']
data_config = config['data']
training_config = config['training']

pretrained_path = model_config['pretrained_path']
model_size = model_config['model_size']
num_classes = model_config['num_classes']
class_names = data_config['class_names']

# %%
model = YOLO(pretrained_path)

print(f"Model type: {type(model)}")
print(f"Model info: {model.info()}")
# Out:
# Model type: <class 'ultralytics.models.yolo.model.YOLO'>
# YOLOv12m summary: 292 layers, 20,201,216 parameters, 0 gradients, 68.1 GFLOPs
# Model info: (292, 20201216, 0, 68.0792576)

# %%
train_args = {
    # 데이터 설정
    'data': str(data_yaml_path),
    
    # 기본 학습 설정
    'epochs': training_config['epochs'],
    'batch': data_config['batch_size'],
    'imgsz': data_config['imgsz'],
    'device': training_config['device'],
    
    # 옵티마이저 설정
    'lr0': model_config['lr0'],
    'lrf': model_config['lrf'],
    'momentum': model_config['momentum'],
    'weight_decay': model_config['weight_decay'],
    
    # Loss 계수
    'box': model_config['box'],
    'cls': model_config['cls'],
    'dfl': model_config['dfl'],
    
    # 학습 설정
    'patience': training_config['patience'],
    'save': training_config['save'],
    'save_period': training_config['save_period'],
    'cache': training_config['cache'],
    'val': training_config['val'],
    'project': training_config['project'],
    'exist_ok': training_config['exist_ok'],
    'plots': training_config['plots'],
    'amp': training_config['amp'],
    'fraction': training_config['fraction'],
    'seed': config['experiment']['seed'],
    
    # 데이터 증강 설정
    'hsv_h': data_config['augmentation']['hsv_h'],
    'hsv_s': data_config['augmentation']['hsv_s'],
    'hsv_v': data_config['augmentation']['hsv_v'],
    'degrees': data_config['augmentation']['degrees'],
    'translate': data_config['augmentation']['translate'],
    'scale': data_config['augmentation']['scale'],
    'shear': data_config['augmentation']['shear'],
    'perspective': data_config['augmentation']['perspective'],
    'flipud': data_config['augmentation']['flipud'],
    'fliplr': data_config['augmentation']['fliplr'],
    'mosaic': data_config['augmentation']['mosaic'],
    'mixup': data_config['augmentation']['mixup'],
    
    # 기타 설정
    'deterministic': config['hardware']['deterministic'],
    'cos_lr': config['hardware']['cos_lr'],
    'close_mosaic': config['hardware']['close_mosaic'],
}

# name이 None이 아닌 경우에만 추가
if training_config.get('name') is not None:
    train_args['name'] = training_config['name']

# None 값 제거
train_args = {k: v for k, v in train_args.items() if v is not None}

# TensorBoard는 환경변수로 활성화
import os
os.environ['TENSORBOARD'] = '1'

# %%
# 학습
result = model.train(**train_args)
# Out:
# New https://pypi.org/project/ultralytics/8.3.248 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.243 🚀 Python-3.12.3 torch-2.5.1+cu118 CUDA:2 (NVIDIA RTX A6000, 48550MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=24, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/data.yaml, degrees=0.0, deterministic=True, device=2, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.003, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=exp/yolo, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1413337  ultralytics.nn.modules.head.Detect           [3, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,139,801 parameters, 20,139,785 gradients, 67.7 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 475.8±101.8 MB/s, size: 706.9 KB)
# train: Scanning /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/labels.cache... 193 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 193/193 392.8Kit/s 0.0s
# train: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/images/stereo20190405_133623_p1_snap_027.jpg: 1 duplicate labels removed
# train: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/images/stereo20190405_133623_p1_snap_036.jpg: 1 duplicate labels removed
# train: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/train/images/stereo20190406_054921_p0_snap_414.jpg: 1 duplicate labels removed
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 264.2±193.6 MB/s, size: 615.1 KB)
# val: Scanning /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/labels.cache... 54 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 54/54 122.5Kit/s 0.0s
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190405_133623_p2_snap_043.jpg: 1 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190405_133623_p2_snap_087.jpg: 2 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190406_054921_p0_snap_544.jpg: 1 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190406_054921_p0_snap_822.jpg: 1 duplicate labels removed
# val: /home/hyeonjin/tomato-detection-agentic/data/TomatOD_YOLO_3/val/images/stereo20190406_065607_p0_snap_080.jpg: 1 duplicate labels removed
# Plotting labels to /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.003' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005625000000000001), 129 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      16.3G      1.744      3.782      1.273         16        640: 100% ━━━━━━━━━━━━ 9/9 1.0s/it 9.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s2.8s
#                    all         54        575      0.814      0.403      0.471      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      18.6G       1.54      2.179      1.136         21        640: 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s2.2s
#                    all         54        575      0.464      0.524      0.424      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      18.6G      1.389       1.22      1.113          6        640: 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s2.0s
#                    all         54        575   0.000617     0.0218    0.00032    0.00018
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      18.6G      1.444      1.212      1.129          8        640: 100% ━━━━━━━━━━━━ 9/9 2.1it/s 4.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s2.2s
#                    all         54        575   0.000622     0.0209   0.000327    0.00014
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      18.6G      1.441      1.148      1.124         13        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s2.0s
#                    all         54        575      0.352     0.0966     0.0184    0.00974
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      18.6G       1.52       1.52      1.162          9        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s1.9s
#                    all         54        575      0.216      0.163     0.0777     0.0287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      18.6G       1.32      2.098      1.014          0        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s1.9s
#                    all         54        575    0.00308     0.0293    0.00135   0.000316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      18.6G       1.42      1.261       1.12          9        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s2.3s
#                    all         54        575      0.242      0.104       0.08     0.0465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      18.6G      1.409      1.237      1.109         18        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s2.9s
#                    all         54        575      0.139      0.248     0.0417     0.0238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      18.6G      1.547      1.316      1.169         21        640: 100% ━━━━━━━━━━━━ 9/9 2.4it/s 3.8s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.9it/s 0.3s0.8s
#                    all         54        575    0.00936    0.00443    0.00605    0.00204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      18.6G       1.54      1.376      1.227          4        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.5it/s 0.4s1.1s
#                    all         54        575      0.269     0.0754     0.0898     0.0518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      18.6G      1.457      1.089      1.147         16        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.2it/s 0.3s0.8s
#                    all         54        575          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      18.6G      1.475      1.081      1.102          6        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.2it/s 0.3s0.8s
#                    all         54        575          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      18.6G      1.447      1.259      1.169          4        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.1it/s 0.3s0.9s
#                    all         54        575      0.638     0.0316     0.0748     0.0477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      18.6G      1.374      1.056      1.091         29        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.257     0.0777     0.0697     0.0428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      18.6G      1.378      1.134       1.12          6        640: 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.9it/s 0.4s1.2s
#                    all         54        575      0.318      0.133     0.0886     0.0566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      18.6G      1.361      1.018      1.076          9        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.0it/s 0.4s1.2s
#                    all         54        575    0.00168    0.00758   0.000605   0.000209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      18.6G      1.386      1.036      1.082         32        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s2.1s
#                    all         54        575      0.663      0.506      0.562       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      18.6G      1.478      1.249      1.198          7        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.4s
#                    all         54        575      0.486      0.247      0.226      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      18.6G      1.362      1.035      1.153          6        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s1.6s
#                    all         54        575      0.464      0.626      0.517      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      18.6G        1.4     0.9825        1.1         10        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s1.9s
#                    all         54        575      0.588      0.657      0.608      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      18.6G      1.343     0.9791      1.086          8        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s2.3s
#                    all         54        575      0.257      0.158      0.104     0.0642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      18.6G      1.294     0.9144      1.047         18        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s1.8s
#                    all         54        575      0.558      0.648      0.662      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      18.6G      1.357     0.9379      1.063         24        640: 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s1.4s
#                    all         54        575      0.555      0.657      0.654      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      18.6G      1.312     0.9309      1.043         11        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s2.3s
#                    all         54        575       0.63      0.571      0.643      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      18.6G      1.313      1.043      1.093         10        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s2.2s
#                    all         54        575      0.595      0.626      0.655      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      18.6G       1.32     0.9874       1.07         14        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s1.9s
#                    all         54        575      0.557      0.586      0.552      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      18.6G      1.289     0.9929      1.036          4        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s1.3s
#                    all         54        575      0.642      0.641       0.65      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      18.6G      1.302     0.9819      1.027         25        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.709       0.67      0.688      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      18.6G      1.252     0.9087      1.041         14        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.5it/s 0.4s1.0s
#                    all         54        575      0.664      0.715      0.695      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      18.6G      1.213     0.9077      1.035          7        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575       0.73      0.739      0.735      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      18.6G      1.219     0.8625      1.024         10        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.715      0.726      0.736      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      18.6G      1.302      1.002      1.037         19        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.9s
#                    all         54        575      0.687      0.753      0.724      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      18.6G      1.266     0.9211      1.014         17        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.701      0.652      0.731      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      18.6G      1.303     0.9573      1.059          9        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.697      0.699      0.724      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      18.6G      1.248     0.8919      1.033          8        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s1.5s
#                    all         54        575      0.633      0.655      0.709      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      18.6G      1.193     0.8575     0.9877          4        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.695      0.709       0.73      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      18.6G      1.202     0.8823      1.033         16        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.615      0.698      0.693      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      18.6G      1.203     0.8758     0.9933         13        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.538      0.638      0.588       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      18.6G       1.21     0.9323      1.012         21        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.688       0.73      0.732      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      18.6G      1.211     0.8362     0.9892          7        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.1it/s 0.4s1.1s
#                    all         54        575      0.538      0.708      0.674      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      18.6G      1.058      1.971     0.8978          0        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.1it/s 0.4s1.1s
#                    all         54        575      0.624      0.676       0.64      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      18.6G      1.206      0.924      1.012         21        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575       0.56       0.67      0.686      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      18.6G      1.217     0.8742     0.9993         27        640: 100% ━━━━━━━━━━━━ 9/9 2.6it/s 3.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.684       0.71      0.717      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      18.6G      1.138     0.8542      1.009         13        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.707      0.717      0.729      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      18.6G      1.153     0.8386     0.9987         11        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.723      0.727      0.725      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      18.6G      1.223     0.8408      1.011         33        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.711      0.741      0.729      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      18.6G      1.195     0.8578     0.9931         16        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.731      0.725       0.72       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      18.6G      1.166      0.792     0.9983         13        640: 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.581      0.667      0.574      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      18.6G       1.18     0.8125      1.006         14        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.717      0.668      0.708      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      18.6G      1.521      2.193      1.075          6        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.708      0.692      0.719      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      18.6G       1.19     0.9243       1.01         18        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.669      0.768      0.746      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      18.6G       1.15     0.7576       1.01         17        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.736      0.751      0.753      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      18.6G      1.084     0.7658      0.981          8        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.697      0.737      0.736      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      18.6G      1.084     0.7596     0.9931          8        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.9s
#                    all         54        575      0.703      0.707      0.714      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      18.6G      1.109      0.771     0.9881          8        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.9s
#                    all         54        575        0.7      0.722      0.726      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      18.6G      1.126     0.7446     0.9846          7        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.699      0.706      0.726      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      18.6G      1.115     0.8021     0.9792          4        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.663      0.655      0.692      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      18.6G      1.099     0.7652     0.9957          7        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.679        0.7      0.687      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      18.6G      1.155     0.8167     0.9797         30        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.682      0.624      0.692       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      18.6G      1.149     0.8239      1.006         20        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.663      0.704      0.702      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      18.6G      1.116     0.8863     0.9802          9        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.677      0.768      0.733      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      18.6G       1.09     0.7176     0.9971         12        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.715      0.712      0.741      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      18.6G      1.084      0.738     0.9827          4        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.685      0.729      0.734      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      18.6G       1.07     0.7673     0.9723         17        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.698      0.749      0.744      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      18.6G      1.166     0.8266     0.9757         38        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.683      0.755      0.745      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      18.6G      1.146     0.7306     0.9765          5        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.648      0.748      0.715      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      18.6G      1.074     0.8062     0.9539         21        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.9s
#                    all         54        575      0.723      0.744      0.753      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      18.6G      1.084      0.734     0.9592         28        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.748      0.737      0.745      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      18.6G      1.018     0.6717     0.9345         14        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.726      0.744      0.735      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      18.6G      1.082     0.7397     0.9504          6        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s0.9s
#                    all         54        575      0.775      0.717      0.736      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      18.6G       1.04     0.6972     0.9503         10        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575       0.73      0.697       0.74      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      18.6G      1.064     0.7338     0.9527         27        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.7it/s 0.4s1.0s
#                    all         54        575      0.653      0.753      0.725      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      18.6G      1.036     0.6842     0.9511          5        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.682      0.734      0.729      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      18.6G      0.975      0.643     0.9394          4        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.713      0.696      0.735      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      18.6G     0.9926       0.67     0.9866          4        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.758      0.665      0.722      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      18.6G       1.05      0.707     0.9625         27        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.1it/s 0.3s0.9s
#                    all         54        575      0.668      0.706      0.701      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      18.6G       1.06     0.7408     0.9769         16        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.642      0.733       0.69      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      18.6G      1.052     0.7203     0.9436         29        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.582      0.738      0.693      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      18.6G      1.053     0.7455     0.9932          6        640: 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.694       0.72        0.7      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      18.6G      1.018     0.7091     0.9703          2        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.0it/s 0.3s1.0s
#                    all         54        575      0.663      0.715      0.717      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      18.6G      1.018     0.7617     0.9629         15        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.697      0.712      0.707      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      18.6G     0.9415     0.6549     0.8793          1        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.713      0.707      0.719      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      18.6G     0.9096      3.036      0.853          0        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.665      0.724      0.732      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      18.6G      1.059      0.701     0.9746          6        640: 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.689      0.727      0.717      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      18.6G     0.9667     0.6568       0.93         13        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.681      0.715      0.699      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      18.6G      1.009     0.6615     0.9379         23        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s1.0s
#                    all         54        575      0.631      0.742      0.718      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      18.6G     0.9961     0.6601     0.9413          5        640: 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.9it/s 0.3s1.0s
#                    all         54        575      0.669      0.752      0.732      0.485
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 68, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 88 epochs completed in 0.099 hours.
# Optimizer stripped from /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5/weights/last.pt, 40.8MB
# Optimizer stripped from /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5/weights/best.pt, 40.8MB
#
# Validating /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5/weights/best.pt...
# Ultralytics 8.3.243 🚀 Python-3.12.3 torch-2.5.1+cu118 CUDA:2 (NVIDIA RTX A6000, 48550MiB)
# YOLOv12m summary (fused): 169 layers, 20,107,225 parameters, 0 gradients, 67.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s1.0s
#                    all         54        575      0.724      0.743      0.752      0.498
#             fully-ripe         43         93        0.7      0.802      0.745      0.498
#              semi-ripe         38        106      0.679      0.604      0.692      0.467
#                 unripe         54        376      0.792      0.824      0.821      0.528
# Speed: 0.1ms preprocess, 3.8ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5

# %%
# 가중치 파일 확인
project_path = Path(PROJECT_ROOT)
weights_dir = project_path / "notebook" / "exp" / "yolo" / "train5"

if weights_dir.exists():
    best_pt = weights_dir/ "weights" / "best.pt"
    last_pt = weights_dir / "weights" / "last.pt"
    
    print(f"\nModel weights:")
    if best_pt.exists():
        print(f"  Best model: {best_pt}")
        print(f"  Size: {best_pt.stat().st_size / 1024 / 1024:.2f} MB")
    if last_pt.exists():
        print(f"  Last model: {last_pt}")
        print(f"  Size: {last_pt.stat().st_size / 1024 / 1024:.2f} MB")

# 결과 파일 확인
results_files = list(Path(results.save_dir).glob("*.csv")) + \
                list(Path(results.save_dir).glob("*.png")) + \
                list(Path(results.save_dir).glob("*.jpg"))
print(f"\nResult files ({len(results_files)}):")
for f in results_files[:10]:  # 처음 10개만 출력
    print(f"  {f.name}")

print("\n" + "=" * 60)
print("Finetuning Completed!")
print("=" * 60)
# Out:
# Model weights:
#   Best model: /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5/weights/best.pt
#   Size: 38.89 MB
#   Last model: /home/hyeonjin/tomato-detection-agentic/notebook/exp/yolo/train5/weights/last.pt
#   Size: 38.89 MB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 18
#      15         print(f"  Size: {last_pt.stat().st_size / 1024 / 1024:.2f} MB")
#      17 # 결과 파일 확인
# ---> 18 results_files = list(Path(results.save_dir).glob("*.csv")) + \
#      19                 list(Path(results.save_dir).glob("*.png")) + \
#      20                 list(Path(results.save_dir).glob("*.jpg"))
#      21 print(f"\nResult files ({len(results_files)}):")
#      22 for f in results_files[:10]:  # 처음 10개만 출력
#
# NameError: name 'results' is not defined
